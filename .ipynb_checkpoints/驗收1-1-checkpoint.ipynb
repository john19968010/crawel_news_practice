# %%
import json
import requests
from lxml import html
from lxml import cssselect
from bs4 import BeautifulSoup as bs

# %%
res = requests.get('https://technews.tw/')

# %%
soup = bs(res.text,'lxml')

# %%
#取到重點觀察他們相同的東西
# soup.select('li.block2014')

# %%
data = soup.select('li.block2014')
# type(data.find('div','cat01')[0])

# %%
data
# Out:
# [<li class="block2014">
#  <div class="cat01">晶片</div>
#  <div class="img">
#  <a href="//technews.tw/2020/05/28/tsmc-delivers-world-first-7nm-automotive-design-enablement-platform/">
#  <div class="height"><img alt="" class="attachment-medium size-medium wp-post-image" height="179" src="https://img.technews.tw/wp-content/uploads/2017/05/08145757/Pro-20134302525558-e1504665348650.jpg" width="300"/></div>
#  <div class="sum_title">
#  <h3>台積電 7 奈米製程介入汽車電子市場，設計實現平台首次投片即成功</h3>
#  </div>
#  </a>
#  </div>
#  <div class="itemelse">
#  <ul>
#  <li class="spotlist">
#  <a href="//technews.tw/2020/05/29/qualcomm-likely-to-sell-smartphone-chips-to-huawei/">華為有望下單給高通？分析師：美商務部應會核准執照</a>
#  </li>
#  <li class="spotlist">
#  <a href="//technews.tw/2020/05/28/tsmc-deferred-equipment-orders/">將遞延部分設備訂單，外資下修台積電 2020 年全年資本支出</a>
#  </li>
#  <li class="spotlist">
#  <a href="//technews.tw/2020/05/28/tsmc-recruits-2-important-washington-lobbyists/">對美關係走鋼索！台積電延攬 2 名重要華盛頓說客</a>
#  </li>
#  </ul>
# ...

# %%
#第一種方法但失敗(因格式不對)
result1 = []
count = 0
for i in data:
    d = {}  
    d['category']= i.find('div','cat01').text.strip()
    d['sum_title']= i.find('div','sum_title').text.strip()
    d['sum_title_url']='http://'+i.find('div','img').find('a').get('href')
    a = []
    for j in resultT[count:]:
        a = []
        a.append(j)
        count +=1
        if 'spotlist' in d:
            d['spotlist'].append(a)
        else:
            d['spotlist'] = a
        if count % 3 == 0:
            break
    result1.append(d)

# %%
result1
# Out:
# [{'category': '晶片',
#   'sum_title': '台積電 7 奈米製程介入汽車電子市場，設計實現平台首次投片即成功',
#   'sum_title_url': 'http:////technews.tw/2020/05/28/tsmc-delivers-world-first-7nm-automotive-design-enablement-platform/',
#   'spotlist': [{'title': '華為有望下單給高通？分析師：美商務部應會核准執照',
#     'url': 'https://technews.tw/2020/05/29/qualcomm-likely-to-sell-smartphone-chips-to-huawei/'},
#    {'title': '將遞延部分設備訂單，外資下修台積電 2020 年全年資本支出',
#     'url': 'https://technews.tw/2020/05/28/tsmc-deferred-equipment-orders/'},
#    [...],
#    {'title': '對美關係走鋼索！台積電延攬 2 名重要華盛頓說客',
#     'url': 'https://technews.tw/2020/05/28/tsmc-recruits-2-important-washington-lobbyists/'},
#    [...]]},
#  {'category': 'Samsung',
#   'sum_title': '積極挑戰 Sony 市占率，三星擴大投資圖像感測器',
#   'sum_title_url': 'http:////technews.tw/2020/05/28/samsung-investment-cis-produce/',
#   'spotlist': [{'title': '三星發表 8 奈米 Exynos 880 5G 行動處理器，搶食中高階主流市場',
#     'url': 'https://technews.tw/2020/05/26/samsung-exynos-880/'},
#    {'title': '三星 Q1 智慧手機出貨量下滑 18%，市占仍居冠',
# ...

# %%
#正確的版本
result = []
for i in data:
    d = {}  
    d['category']= i.find('div','cat01').text.strip()
    d['sum_title']= i.find('div','sum_title').text.strip()
    d['sum_title_url']='https:'+i.find('div','img').find('a').get('href')
    a = []
    for j in range(3):
        d1 = {}
        d1['title']=i.find_all('li','spotlist')[j].text.strip()
        d1['url']='https:'+i.find_all('li','spotlist')[j].a.get('href')
        a.append(d1)
    d['spotlist']= a
    result.append(d)

# %%
result
# Out:
# [{'category': '晶片',
#   'sum_title': '台積電 7 奈米製程介入汽車電子市場，設計實現平台首次投片即成功',
#   'sum_title_url': 'https://technews.tw/2020/05/28/tsmc-delivers-world-first-7nm-automotive-design-enablement-platform/',
#   'spotlist': [{'title': '華為有望下單給高通？分析師：美商務部應會核准執照',
#     'url': 'https://technews.tw/2020/05/29/qualcomm-likely-to-sell-smartphone-chips-to-huawei/'},
#    {'title': '將遞延部分設備訂單，外資下修台積電 2020 年全年資本支出',
#     'url': 'https://technews.tw/2020/05/28/tsmc-deferred-equipment-orders/'},
#    {'title': '對美關係走鋼索！台積電延攬 2 名重要華盛頓說客',
#     'url': 'https://technews.tw/2020/05/28/tsmc-recruits-2-important-washington-lobbyists/'}]},
#  {'category': 'Samsung',
#   'sum_title': '積極挑戰 Sony 市占率，三星擴大投資圖像感測器',
#   'sum_title_url': 'https://technews.tw/2020/05/28/samsung-investment-cis-produce/',
#   'spotlist': [{'title': '三星發表 8 奈米 Exynos 880 5G 行動處理器，搶食中高階主流市場',
#     'url': 'https://technews.tw/2020/05/26/samsung-exynos-880/'},
#    {'title': '三星 Q1 智慧手機出貨量下滑 18%，市占仍居冠',
# ...

# %%
#  result

# %%
#存成json檔
import json
fn = 'Exam1_1.json'
with open (fn,'w',encoding = 'utf8') as file:
    json.dump(result,file,ensure_ascii=False)
    #py會內建ascii為true 而漢字也包含在ascii的字符裡面 故之後讀取會自動變成ascii而不是utf8

# %%
# soup.select('div>div>ul')[2].find_all('li','spotlist')

# %%
#第一種方法(以下都是)
#原本想將spotlist的小項都抓出來再放到主迴圈之中
#以下為抓小項的過程
spot = soup.select('div>div>ul')[2].find_all('li','spotlist')

# %%
resultT = []
for i in spot:
    d = {}
    d['title']=i.find('a').text.strip()
    d['url']='https:'+i.find('a').get('href')
    resultT.append(d)
# print(resultT)

# %%
data = soup.select('div>div>ul')[2]

# %%
 resultT
# Out:
# [{'title': '華為有望下單給高通？分析師：美商務部應會核准執照',
#   'url': 'https://technews.tw/2020/05/29/qualcomm-likely-to-sell-smartphone-chips-to-huawei/'},
#  {'title': '將遞延部分設備訂單，外資下修台積電 2020 年全年資本支出',
#   'url': 'https://technews.tw/2020/05/28/tsmc-deferred-equipment-orders/'},
#  {'title': '對美關係走鋼索！台積電延攬 2 名重要華盛頓說客',
#   'url': 'https://technews.tw/2020/05/28/tsmc-recruits-2-important-washington-lobbyists/'},
#  {'title': '三星發表 8 奈米 Exynos 880 5G 行動處理器，搶食中高階主流市場',
#   'url': 'https://technews.tw/2020/05/26/samsung-exynos-880/'},
#  {'title': '三星 Q1 智慧手機出貨量下滑 18%，市占仍居冠',
#   'url': 'https://technews.tw/2020/05/26/samsung-q1-smartphone-shipments-decline-market-share-still-tops/'},
#  {'title': '華為遭美圍剿撼動供應鏈，日經：台積電、三星對峙更嚴重',
#   'url': 'https://technews.tw/2020/05/26/samsung-tsmc-rivalry-heats-up-as-us-cracks-down-on-huawei/'},
#  {'title': '就是不花錢買廣告，特斯拉又賺到 NASA 免費曝光機會',
#   'url': 'https://technews.tw/2020/05/28/tesla-get-free-ad-from-nasa-mission/'},
#  {'title': '拚買氣！特斯拉北美、中國大降價，折價最高 5 千美元',
# ...
